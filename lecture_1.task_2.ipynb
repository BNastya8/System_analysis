# %% [markdown]
# |**Вопрос для изучения**|	**Каскадная модель**|	**Scrum**|
# | --- | --- | --- |
# |В чем заключается основная особенность выбранного подхода?|	модель процесса разработки программного обеспечения, в которой процесс разработки выглядит как поток, последовательно проходящий фазы анализа требований, проектирования, реализации, тестирования, интеграции и поддержки.|	минимально необходимый набор мероприятий, артефактов, ролей, на которых строится процесс Scrum-разработки, позволяющий за фиксированные небольшие промежутки времени, называемые спринтами, предоставлять конечному пользователю работающий продукт с новыми бизнес-возможностями (инкремент), для которых определён наибольший приоритет.|
# |Какие компании применяют выбранный подход?|	Cisco, IBM, AT Consulting|	Netflix, Google, Microsoft|
# |Может ли выбранные подход (команда в нем) существовать без руководителя без потери качества или эффективности?|	Нет|	Да|
# |Какие проекты / продукты из мира IT (приложения, системы) можно, оправдано, целесообразно разрабатывать, используя выбранных подход?|	Cisco Secure Endpoint (решение, предназначенное для защиты), IBM SPSS (аналитическое программное обеспечение),  IBM Application Performance Management (инструментарий помогающий управлять), Система Управления Доступом (СУД) от AT Consulting (предназначена для автоматизации )|	netflix (платформа), amazon (интернет магазин), portal 2(компьютерная игра)|
# |Какие проекты / продукты из мира IT (приложения, системы) нельзя, нецелесообразно разрабатывать, используя выбранных подход?|	Baldur’s Gate III (компьютерная игра), Ozon (приложение продажи), skillfactory(образовательная платформа)|	Госуслуги (портал государственных услуг), The day before(компьютерная игра от новичков), kaspersky(антивирус)|
